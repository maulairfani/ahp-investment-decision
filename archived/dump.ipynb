# %%
import pandas as pd

# %%
sector = pd.read_csv("../data/sector.csv")

# %%
sector['sector'].unique()
# Out:
# array(['Barang Konsumen Primer', 'Kesehatan', 'Keuangan',
#        'Barang Konsumen Non-Primer', 'Properti & Real Estat',
#        'Perindustrian', 'Energi', 'Barang Baku', 'Infrastruktur',
#        'Teknologi', 'Transportasi & Logistik'], dtype=object)

# %%
sector_pilihan = ['Kesehatan', 'Energi', 'Teknologi']

# %%
sector
# Out:
#                       sector ticker
# 0     Barang Konsumen Primer   AMRT
# 1     Barang Konsumen Primer   MLPL
# 2     Barang Konsumen Primer   MPPA
# 3     Barang Konsumen Primer   TAPG
# 4     Barang Konsumen Primer   MIDI
# ..                       ...    ...
# 917  Transportasi & Logistik   MIRA
# 918  Transportasi & Logistik   BLTA
# 919  Transportasi & Logistik   KLAS
# 920  Transportasi & Logistik   RCCC
# 921  Transportasi & Logistik   LOPI
#
# [922 rows x 2 columns]

# %%
df = pd.read_csv("../data/temps/alternatives.csv")
df
# Out:
#   Ticker Code  Current Ratio (Quarter) Current Share Outstanding  \
# 0        ASII                     1.33                   40.48 B
# 1        BYAN                     1.42                   33.33 B
# 2        DSSA                     1.68                  770.55 M
# 3        UNTR                     1.46                    3.73 B
# 4        ADRO                     2.01                   31.99 B
# 5        DCII                     1.34                    2.38 B
#
#    Debt to Equity Ratio (Quarter) Enterprise Value  EPS Growth Streak  \
# 0                            0.47     312,442.30 B                4.0
# 1                            0.21     629,628.90 B                8.0
# 2                            0.37     101,172.43 B                4.0
# 3                            0.24      95,239.17 B                6.0
# 4                            0.21      67,234.67 B                5.0
# 5                            0.51      85,411.41 B                3.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Ticker Code                           6 non-null      object
#  1   Current Ratio (Quarter)               6 non-null      float64
#  2   Current Share Outstanding             6 non-null      object
#  3   Debt to Equity Ratio (Quarter)        6 non-null      float64
#  4   Enterprise Value                      6 non-null      object
#  5   EPS Growth Streak                     6 non-null      float64
#  6   Market Cap                            6 non-null      object
#  7   Net Profit Margin (TTM)(%)            6 non-null      object
#  8   Current Price to Book Value           6 non-null      float64
#  9   Current PE Ratio (TTM)                6 non-null      float64
#  10  Current Price To Free Cashflow (TTM)  6 non-null      float64
# ...

# %%
df["Current Share Outstanding"].str[:-2]
# Out:
# 0     40.48 B
# 1     33.33 B
# 2    770.55 M
# 3      3.73 B
# 4     31.99 B
# 5      2.38 B
# Name: Current Share Outstanding, dtype: object
